# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import scipy.sparse.linalg as spla
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# Junction tables must be filled when new user signed up!

book_df = pd.read_csv('./clubs_book.csv', encoding = "Latin1", sep = ",")
user_df = pd.read_csv('./clubs_user.csv', encoding = "Latin1", sep = ",")
club_df = pd.read_csv('./clubs_club.csv', encoding = "Latin1", sep = ",")
club_book_df = pd.read_csv('./clubs_club_books.csv', encoding = "Latin1", sep = ",")
club_user_df = pd.read_csv('./clubs_club_users.csv', encoding = "Latin1", sep = ",")
user_book_df = pd.read_csv('./clubs_user_books.csv', encoding = 'Latin1', sep = ',')

# %%
# Merge club_user junction table with user table to get ages of all users

club_user_age_df = club_user_df.merge(user_df, left_on = 'user_id', right_on = 'id')
club_user_age_df = club_user_age_df[['id_x', 'club_id', 'user_id', 'age']]
club_user_age_df = club_user_age_df.rename(columns={'id_x':'club_user_id'}).sort_values('club_user_id', ascending=True)

club_user_age_df
# Out:
#      club_user_id  club_id  user_id  age
# 0               1        2   207351  115
# 1               2        2   241265  136
# 3               3        1    11909   41
# 6               4        5    31325  143
# 7               5        4   249795  114
# ..            ...      ...      ...  ...
# 12            496       10    72722   57
# 455           497        8   216249  103
# 294           498        2   144369   75
# 187           499        2   185348   83
# 499           500        2   245875   78
#
# [500 rows x 4 columns]

# %%
# Merge club_user junction table with club table to get locations of all clubs

club_user_location_df = club_user_df.merge(club_df, left_on = 'club_id', right_on = 'id')
club_user_location_df = club_user_location_df[['id_x', 'club_id', 'user_id', 'location']]
club_user_location_df = club_user_location_df.rename(columns={'id_x':'club_user_id'}).sort_values('club_user_id', ascending=True)

club_user_location_df
# Out:
#      club_user_id  club_id  user_id                location
# 0               1        2   207351            Tokyo, Japan
# 1               2        2   241265            Tokyo, Japan
# 63              3        1    11909     Adelaide, Australia
# 108             4        5    31325  Sharm El Sheikh, Egypt
# 156             5        4   249795            Luxor, Egypt
# ..            ...      ...      ...                     ...
# 455           496       10    72722              London, UK
# 360           497        8   216249            Delhi, India
# 60            498        2   144369            Tokyo, Japan
# 61            499        2   185348            Tokyo, Japan
# 62            500        2   245875            Tokyo, Japan
#
# [500 rows x 4 columns]

# %%
# Merge the club_user_age and club_user_location tables to have all in one table

club_user_age_location_df = club_user_age_df.merge(club_user_location_df, left_on = 'club_user_id', right_on = 'club_user_id')
club_user_age_location_df = club_user_age_location_df[['club_user_id', 'club_id_x', 'user_id_x', 'age', 'location']]
club_user_age_location_df = club_user_age_location_df.rename(columns={'user_id_x':'user_id', 'club_id_x':'club_id'})

club_user_age_location_df
# Out:
#      club_user_id  club_id  user_id  age                location
# 0               1        2   207351  115            Tokyo, Japan
# 1               2        2   241265  136            Tokyo, Japan
# 2               3        1    11909   41     Adelaide, Australia
# 3               4        5    31325  143  Sharm El Sheikh, Egypt
# 4               5        4   249795  114            Luxor, Egypt
# ..            ...      ...      ...  ...                     ...
# 495           496       10    72722   57              London, UK
# 496           497        8   216249  103            Delhi, India
# 497           498        2   144369   75            Tokyo, Japan
# 498           499        2   185348   83            Tokyo, Japan
# 499           500        2   245875   78            Tokyo, Japan
#
# [500 rows x 5 columns]

# %%
# Get average age of each club

average_club_age_df = pd.merge(club_user_age_df, club_df, left_on='club_id', right_on='id') \
    .groupby(['club_id', 'name'])['age'].mean().reset_index(name = 'age')

average_club_age_df = average_club_age_df.rename(columns={'age':'average_age'})

average_club_age_df
# Out:
#    club_id                    name  average_age
# 0        1    SarahMatthews's Club    62.400000
# 1        2        HelenGray's Club    69.857143
# 2        3    RhysNicholson's Club    66.660377
# 3        4       KarenQuinn's Club    61.720000
# 4        5    CameronHarvey's Club    80.979167
# 5        6   ArthurShepherd's Club    65.490909
# 6        7  FrancesPhillips's Club    77.886364
# 7        8   SylviaFranklin's Club    87.106383
# 8        9      GeorgeBryan's Club    75.925000
# 9       10        CarolKing's Club    68.672727

# %%
# Add column for age difference and return clubs in ascending order of difference from my age

my_age = 65
average_club_age_df['age_difference'] = pd.DataFrame(abs(average_club_age_df['average_age'] - my_age))
average_club_age_df = average_club_age_df.sort_values('age_difference', ascending=True)
average_club_age_df
# Out:
#    club_id                    name  average_age  age_difference
# 5        6   ArthurShepherd's Club    65.490909        0.490909
# 2        3    RhysNicholson's Club    66.660377        1.660377
# 0        1    SarahMatthews's Club    62.400000        2.600000
# 3        4       KarenQuinn's Club    61.720000        3.280000
# 9       10        CarolKing's Club    68.672727        3.672727
# 1        2        HelenGray's Club    69.857143        4.857143
# 8        9      GeorgeBryan's Club    75.925000       10.925000
# 6        7  FrancesPhillips's Club    77.886364       12.886364
# 4        5    CameronHarvey's Club    80.979167       15.979167
# 7        8   SylviaFranklin's Club    87.106383       22.106383

# %%
# Return top 10 closest aged club IDs

closest_age_clubs_df = average_club_age_df['club_id'].iloc[0:5]
closest_age_clubs_df
# Out:
# 5     6
# 2     3
# 0     1
# 3     4
# 9    10
# Name: club_id, dtype: int64

# %%
# Merge closest aged club IDs with clubs CSV to get all details
closest_age_clubs_df = closest_age_clubs_df.reset_index().rename(columns={'club_id':'id'})
closest_age_clubs_df = pd.merge(closest_age_clubs_df, club_df, on = 'id')

closest_age_clubs_df
# Out:
#    index  id                   name             location  \
# 0      5   6  ArthurShepherd's Club       Ottawa, Canada
# 1      2   3   RhysNicholson's Club    Sao Paulo, Brazil
# 2      0   1   SarahMatthews's Club  Adelaide, Australia
# 3      3   4      KarenQuinn's Club         Luxor, Egypt
# 4      9  10       CarolKing's Club           London, UK
#
#                                          description  avg_reading_speed  \
# 0  Eius labore dicta quaerat.\r\nAssumenda necess...                316
# 1  Commodi a debitis beatae repellat sunt nesciun...                 79
# 2  Iusto repellat inventore nihil reiciendis. Dis...                364
# 3  Sed dolorum in totam ad dolore. Magnam cum ea ...                384
# 4  Repellat iure sed reprehenderit amet similique...                158
#
#    owner_id
# 0        78
# 1     68227
# 2    271772
# 3    209308
# 4     10319

# %%
# Return clubs with matching location (exact)

my_location = 'Adelaide, Australia'

location_match = club_df['location'] == my_location
closest_location_clubs_df = club_df[location_match]

closest_location_clubs_df
# Out:
#    id                  name             location  \
# 0   1  SarahMatthews's Club  Adelaide, Australia
#
#                                          description  avg_reading_speed  \
# 0  Iusto repellat inventore nihil reiciendis. Dis...                364
#
#    owner_id
# 0    271772

# %%
# Return clubs with matching location (using fuzzy search)

my_location = 'AdelAustralia'

def get_ratio(row):
    club_location = row['location']
    return fuzz.token_sort_ratio(club_location, my_location)

closest_club_location_fuzzy_df = club_df[club_df.apply(get_ratio, axis=1) > 35]
closest_club_location_fuzzy_df['location_fuzzy_score'] = club_df.apply(get_ratio, axis=1)
closest_club_location_fuzzy_df = closest_club_location_fuzzy_df.sort_values('location_fuzzy_score', ascending=False)

closest_club_location_fuzzy_df
# Out:
# /var/folders/88/bz478lf11_q907pdrr_44p9c0000gn/T/ipykernel_6524/242678225.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closest_club_location_fuzzy_df['location_fuzzy_score'] = club_df.apply(get_ratio, axis=1)
#    id                   name             location  \
# 0   1   SarahMatthews's Club  Adelaide, Australia
# 5   6  ArthurShepherd's Club       Ottawa, Canada
# 8   9     GeorgeBryan's Club      Ibadan, Nigeria
# 7   8  SylviaFranklin's Club         Delhi, India
# 2   3   RhysNicholson's Club    Sao Paulo, Brazil
#
#                                          description  avg_reading_speed  \
# 0  Iusto repellat inventore nihil reiciendis. Dis...                364
# 5  Eius labore dicta quaerat.\r\nAssumenda necess...                316
# 8  Voluptatem tempora saepe itaque nostrum recusa...                343
# 7  Asperiores debitis tenetur natus asperiores. A...                130
# 2  Commodi a debitis beatae repellat sunt nesciun...                 79
#
#    owner_id  location_fuzzy_score
# 0    271772                    84
# 5        78                    46
# 8     47409                    44
# 7    128231                    42
# 2     68227                    41

# %%
# Perform a many-to-many merge to get the favourite books of each club

club_favourite_books_df = pd.merge(pd.merge(club_df, club_book_df, left_on='id', right_on='club_id'), 
                    pd.merge(book_df, club_book_df, left_on='id', right_on='book_id'), on='book_id', how = 'inner') \
                        .groupby(['club_id_x', 'name', 'ISBN'])['title', 'author'].agg(list).reset_index()

club_favourite_books_df = club_favourite_books_df.rename(columns={'club_id_x':'club_id'})

club_favourite_books_df
# Out:
# /var/folders/88/bz478lf11_q907pdrr_44p9c0000gn/T/ipykernel_6524/536270985.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   club_favourite_books_df = pd.merge(pd.merge(club_df, club_book_df, left_on='id', right_on='club_id'),
#     club_id                    name        ISBN  \
# 0         1    SarahMatthews's Club  0140016929
# 1         1    SarahMatthews's Club  0671685244
# 2         1    SarahMatthews's Club  0688026826
# 3         1    SarahMatthews's Club  0785809880
# 4         1    SarahMatthews's Club  0812565665
# 5         2        HelenGray's Club  0023376627
# 6         2        HelenGray's Club  0192816640
# 7         2        HelenGray's Club  0198319746
# 8         2        HelenGray's Club  0764507508
# 9         2        HelenGray's Club  0965064573
# 10        3    RhysNicholson's Club  0553104489
# 11        3    RhysNicholson's Club  0590429949
# 12        3    RhysNicholson's Club  0704381176
# 13        3    RhysNicholson's Club  1563054345
# 14        3    RhysNicholson's Club  1880188481
# 15        4       KarenQuinn's Club  0373632479
# 16        4       KarenQuinn's Club  0395544262
# 17        4       KarenQuinn's Club  0425086607
# 18        4       KarenQuinn's Club  0895773767
# 19        4       KarenQuinn's Club  843501665X
# 20        5    CameronHarvey's Club  0060199261
# 21        5    CameronHarvey's Club  0523405731
# 22        5    CameronHarvey's Club  0590120603
# 23        5    CameronHarvey's Club  0590319914
# 24        5    CameronHarvey's Club  0890871094
# 25        6   ArthurShepherd's Club  0373273495
# 26        6   ArthurShepherd's Club  0385486448
# 27        6   ArthurShepherd's Club  0553263447
# 28        6   ArthurShepherd's Club  0812505832
# 29        6   ArthurShepherd's Club  083352965X
# 30        7  FrancesPhillips's Club  0312167709
# 31        7  FrancesPhillips's Club  0373053045
# 32        7  FrancesPhillips's Club  0523405731
# 33        7  FrancesPhillips's Club  0670803790
# 34        7  FrancesPhillips's Club  0865650675
# 35        8   SylviaFranklin's Club  0006928145
# 36        8   SylviaFranklin's Club  0373261977
# 37        8   SylviaFranklin's Club  0373286856
# 38        8   SylviaFranklin's Club  0553289322
# 39        8   SylviaFranklin's Club  0865650675
# 40        9      GeorgeBryan's Club  0027888452
# 41        9      GeorgeBryan's Club  0385336276
# 42        9      GeorgeBryan's Club  0441011705
# 43        9      GeorgeBryan's Club  0890872384
# 44        9      GeorgeBryan's Club  2831563836
# 45       10        CarolKing's Club  0060192321
# 46       10        CarolKing's Club  0140285563
# 47       10        CarolKing's Club  0393703703
# 48       10        CarolKing's Club  0679441700
# 49       10        CarolKing's Club  0821773801
#
#                                                 title  \
# 0                                   [From London Far]
# 1   [DEAD ON TARGET (HB #1) (Hardy Boys Casefiles ...
# 2                                      [Shadow Magic]
# 3          [The Pre-Raphaelites (Centuries of Style)]
# 4                                [A Cure for Gravity]
# 5                              [The Conscious Reader]
# 6   [The Expedition of Humphry Clinker (The World'...
# 7   [Twelfth Night (Oxford School Shakespeare Seri...
# 8   [Digital Photography for Dummies, Quick Refere...
# 9   [Ferocious Romance:  What My Encounters With T...
# 10                           [Hawk O'Toole's Hostage]
# 11                          [Molly by Any Other Name]
# 12  [The Abolition of Britain: From Lady Chatterly...
# 13                                   [The Wine Bible]
# 14     [Hawaii Pono: An Ethnic and Political History]
# 15          [Wolf's Bane (Destroyer Series, No. 132)]
# 16                                    [Fox in a Trap]
# 17        [Watchtower (Chronicles of Tornor, Book 1)]
# 18  [Nature in America/Your A to Z Guide to Our Co...
# 19                           [El Puente de Alcantara]
# 20                     [The Bronze Horseman: A Novel]
# 21                       [Bitter Honey, Bitter Honey]
# 22  [Quest for Camelot: A Storybook (Quest for Cam...
# 23                               [Farm Alphabet Book]
# 24                                      [Self-Esteem]
# 25  [The Right Stuff (Silhouette Intimate Moments,...
# 26  [Dangerous Games: Ice Climbing, Storm Kayaking...
# 27                     [The Warrior Who Carried Life]
# 28                             [Chapel of the Ravens]
# 29  [The Yellow House Mystery (Boxcar Children (Li...
# 30  [America's Favorite Inns, B&Bs, & Small Hotels...
# 31       [Misty Splendor (Silhouette Desire, No 304)]
# 32                       [Bitter Honey, Bitter Honey]
# 33                           [Company of Adventurers]
# 34  [A Redoute Treasury: 468 Watercolours from Les...
# 35  [The Strange Message in the Parchment (The Nan...
# 36                                       [Love Bytes]
# 37   [Stark Lightning (Harlequin Historical, No. 85)]
# 38                                          [Scandal]
# 39  [A Redoute Treasury: 468 Watercolours from Les...
# 40                          [Coyote Places the Stars]
# 41                                         [Top Hook]
# 42                    [The Many Faces of Van Helsing]
# 43                           [North of San Francisco]
# 44  [Dic Portuguese-English Dictionary/Dicionario ...
# 45  [Expedition Whydah: The Story of the World's F...
# 46     [The Diary of a Nobody (Essential.penguin S.)]
# 47  [E-Therapy: Case Studies, Guiding Principles, ...
# 48  [The Run of His Life: The People V. O.J. Simpson]
# 49                                     [Midnight Sun]
#
#                                   author
# 0                        [Michael Innes]
# 1                    [Franklin W. Dixon]
# 2                        [Seymour Simon]
# 3                      [Inc. Book Sales]
# 4                     [Arthur Rosenfeld]
# 5                    [Caroline Schrodes]
# 6                      [Tobias Smollett]
# 7                            [Roma Gill]
# 8                      [David D.  Busch]
# 9                      [Donna Minkowitz]
# 10                        [Sandra Brown]
# 11                 [Jean Davies Okimoto]
# 12                      [Peter Hitchens]
# 13                       [Karen MacNeil]
# 14                   [Lawrence H. Fuchs]
# 15                       [Warren Murphy]
# 16                    [Jane Resh Thomas]
# 17                   [Elizabeth A. Lynn]
# 18                [Not Applicable (Na )]
# 19                          [Frank Baer]
# 20                     [Paullina Simons]
# 21  [Avis Worthington, Avis Worthington]
# 22                       [James Patrick]
# 23                         [Jane Miller]
# 24                   [Virginia M. Satir]
# 25                    [Merline Lovelace]
# 26                    [Andrew Todhunter]
# 27                         [Geoff Ryman]
# 28                         [Paul Bishop]
# 29                     [Gertrude Warner]
# 30                     [Sandra W. Soule]
# 31                        [Laurie Paige]
# 32  [Avis Worthington, Avis Worthington]
# 33                     [Peter C. Newman]
# 34        [Peter Mallary, Peter Mallary]
# 35                       [Carolyn Keene]
# 36                       [Sally Chapman]
# 37                         [Elaine Rome]
# 38                        [Amanda Quick]
# 39        [Peter Mallary, Peter Mallary]
# 40                 [Harriet Peck Taylor]
# 41                         [GORDON KENT]
# 42                      [Jeanne Cavelos]
# 43                       [Robert Matson]
# 44                  [Berlitz Publishing]
# 45                      [Barry Clifford]
# 46                    [George Grossmith]
# 47                    [Robert C. Hsiung]
# 48                      [Jeffrey Toobin]
# 49                          [Kat Martin]

# %%
# Perform a many-to-many merge to get the favourite books of each user

user_favourite_books_df = pd.merge(pd.merge(user_df, user_book_df, left_on='id', right_on='user_id'), 
                    pd.merge(book_df, user_book_df, left_on='id', right_on='book_id'), on='book_id', how = 'inner') \
                       .groupby(['user_id_x', 'first_name','last_name', 'ISBN', 'title', 'author'])['title', 'author'].agg(list).reset_index()

user_favourite_books_df = user_favourite_books_df.rename(columns={'user_id_x':'user_id'})
user_favourite_books_df = user_favourite_books_df.drop(0, 1)
user_favourite_books_df
# Out:
# /var/folders/88/bz478lf11_q907pdrr_44p9c0000gn/T/ipykernel_6524/4122145811.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   user_favourite_books_df = pd.merge(pd.merge(user_df, user_book_df, left_on='id', right_on='user_id'),
# /var/folders/88/bz478lf11_q907pdrr_44p9c0000gn/T/ipykernel_6524/4122145811.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   user_favourite_books_df = user_favourite_books_df.drop(0, 1)
#       user_id first_name last_name        ISBN  \
# 0          78     Arthur  Shepherd  0373122675
# 1          78     Arthur  Shepherd  042512214X
# 2          78     Arthur  Shepherd  0451522184
# 3          78     Arthur  Shepherd  0732250927
# 4          78     Arthur  Shepherd  3499231093
# ...       ...        ...       ...         ...
# 2476   276432       Ruth     Sharp  0688026826
# 2477   276432       Ruth     Sharp  0821773801
# 2478   276432       Ruth     Sharp  0865650675
# 2479   276432       Ruth     Sharp  0872261670
# 2480   276432       Ruth     Sharp  0874771595
#
#                                                   title  \
# 0     To Marry McCloud  (Bachelor Cousins) (Harlequi...
# 1                 Sisters in Crime 3 (Sisters in Crime)
# 2                                The Pilgrims' Progress
# 3                  Surfside High: Sandy (Surfside High)
# 4             Traum im Herbst. Und andere StÃ?ÃÂ¼cke.
# ...                                                 ...
# 2476                                       Shadow Magic
# 2477                                       Midnight Sun
# 2478  A Redoute Treasury: 468 Watercolours from Les ...
# 2479  Solved!: Famous Mystery Writers on Classic Tru...
# 2480                          Overcoming Writing Blocks
#
#                           author
# 0                Carole Mortimer
# 1                Marilyn Wallace
# 2                    John Bunuan
# 3                Virginia Baxter
# 4                      Jon Fosse
# ...                          ...
# 2476               Seymour Simon
# 2477                  Kat Martin
# 2478               Peter Mallary
# 2479          Richard Glyn Jones
# 2480  Karin and Skjei, Eric MacK
#
# [2481 rows x 6 columns]

# %%
# Get the favourite books and authors of one user (me)

my_id = 78
my_favourite_books_df = user_favourite_books_df.loc[user_favourite_books_df['user_id'] == my_id]
my_favourite_books_df
# Out:
#    user_id first_name last_name        ISBN  \
# 0       78     Arthur  Shepherd  0373122675
# 1       78     Arthur  Shepherd  042512214X
# 2       78     Arthur  Shepherd  0451522184
# 3       78     Arthur  Shepherd  0732250927
# 4       78     Arthur  Shepherd  3499231093
#
#                                                title           author
# 0  To Marry McCloud  (Bachelor Cousins) (Harlequi...  Carole Mortimer
# 1              Sisters in Crime 3 (Sisters in Crime)  Marilyn Wallace
# 2                             The Pilgrims' Progress      John Bunuan
# 3               Surfside High: Sandy (Surfside High)  Virginia Baxter
# 4          Traum im Herbst. Und andere StÃ?ÃÂ¼cke.        Jon Fosse

# %%
# Get the favourite books and authors of one club

club_id = 8
single_club_favourite_books_df = club_favourite_books_df.loc[club_favourite_books_df['club_id'] == club_id]
single_club_favourite_books_df
# Out:
#     club_id                   name        ISBN  \
# 35        8  SylviaFranklin's Club  0006928145
# 36        8  SylviaFranklin's Club  0373261977
# 37        8  SylviaFranklin's Club  0373286856
# 38        8  SylviaFranklin's Club  0553289322
# 39        8  SylviaFranklin's Club  0865650675
#
#                                                 title  \
# 35  [The Strange Message in the Parchment (The Nan...
# 36                                       [Love Bytes]
# 37   [Stark Lightning (Harlequin Historical, No. 85)]
# 38                                          [Scandal]
# 39  [A Redoute Treasury: 468 Watercolours from Les...
#
#                             author
# 35                 [Carolyn Keene]
# 36                 [Sally Chapman]
# 37                   [Elaine Rome]
# 38                  [Amanda Quick]
# 39  [Peter Mallary, Peter Mallary]

# %%
# TO DO: Currently only checks against one favourite book, make sure it checks against all favourite books

# Return clubs with matching favourite books (using fuzzy search)

my_favourite_book = 'The Strange Message in the Parchment'

def get_ratio(row):
    book_title = row['title']
    return fuzz.token_sort_ratio(book_title, my_favourite_book)

closest_club_books_fuzzy_df = club_favourite_books_df[club_favourite_books_df.apply(get_ratio, axis=1) > 60]
closest_club_books_fuzzy_df['favourite_books_fuzzy_score'] = club_favourite_books_df.apply(get_ratio, axis=1)
closest_club_books_fuzzy_df = closest_club_books_fuzzy_df.sort_values('favourite_books_fuzzy_score', ascending=False)

closest_club_books_fuzzy_df
# Out:
# /var/folders/88/bz478lf11_q907pdrr_44p9c0000gn/T/ipykernel_6524/2267200596.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closest_club_books_fuzzy_df['favourite_books_fuzzy_score'] = club_favourite_books_df.apply(get_ratio, axis=1)
#     club_id                   name        ISBN  \
# 35        8  SylviaFranklin's Club  0006928145
#
#                                                 title           author  \
# 35  [The Strange Message in the Parchment (The Nan...  [Carolyn Keene]
#
#     favourite_books_fuzzy_score
# 35                           74

# %%
# TO DO: Currently only checks against one favourite author, make sure it checks against all favourite authors

# Return clubs with matching favourite authors (using fuzzy search)

my_favourite_author = 'jeff ryman'

def get_ratio(row):
    book_author = row['author']
    return fuzz.token_sort_ratio(book_author, my_favourite_author)

closest_club_authors_fuzzy_df = club_favourite_books_df[club_favourite_books_df.apply(get_ratio, axis=1) > 80]
closest_club_authors_fuzzy_df['favourite_authors_fuzzy_score'] = club_favourite_books_df.apply(get_ratio, axis=1)
closest_club_authors_fuzzy_df = closest_club_authors_fuzzy_df.sort_values('favourite_authors_fuzzy_score', ascending=False).dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

closest_club_authors_fuzzy_df
# Out:
# /var/folders/88/bz478lf11_q907pdrr_44p9c0000gn/T/ipykernel_6524/2028762527.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closest_club_authors_fuzzy_df['favourite_authors_fuzzy_score'] = club_favourite_books_df.apply(get_ratio, axis=1)
#     club_id                   name        ISBN  \
# 27        6  ArthurShepherd's Club  0553263447
#
#                              title         author  \
# 27  [The Warrior Who Carried Life]  [Geoff Ryman]
#
#     favourite_authors_fuzzy_score
# 27                             86

# %%
# TO DO: Implement algorithm which uses age, location, favourite books and favourite authors

# %% [markdown]
# <h1> Our work ends here </h1>

# %%
club_user_age_location_pivot_matrix_df = club_user_age_location_df.pivot(index='user_id', 
                                                          columns='club_id').fillna(0)

club_user_age_location_pivot_matrix_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/laurenceandrews/KCL/5CCS2SEG/sick-legends/clubs/club-to-user-recommender/club-to-user-recommender.ipynb Cell 20' in <module>
# ----> <a href='vscode-notebook-cell:/Users/laurenceandrews/KCL/5CCS2SEG/sick-legends/clubs/club-to-user-recommender/club-to-user-recommender.ipynb#ch0000019?line=0'>1</a> club_user_age_location_pivot_matrix_df = club_user_age_location_df.pivot(index='user_id',
#       <a href='vscode-notebook-cell:/Users/laurenceandrews/KCL/5CCS2SEG/sick-legends/clubs/club-to-user-recommender/club-to-user-recommender.ipynb#ch0000019?line=1'>2</a>                                                           columns='club_id').fillna(0)
#       <a href='vscode-notebook-cell:/Users/laurenceandrews/KCL/5CCS2SEG/sick-legends/clubs/club-to-user-recommender/club-to-user-recommender.ipynb#ch0000019?line=3'>4</a> club_user_age_location_pivot_matrix_df.head()
#
# File ~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py:7876, in DataFrame.pivot(self, index, columns, values)
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=7870'>7871</a> @Substitution("")
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=7871'>7872</a> @Appender(_shared_docs["pivot"])
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=7872'>7873</a> def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=7873'>7874</a>     from pandas.core.reshape.pivot import pivot
# -> <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=7875'>7876</a>     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:520, in pivot(data, index, columns, values)
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/pivot.py?line=517'>518</a>     else:
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/pivot.py?line=518'>519</a>         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/pivot.py?line=519'>520</a> return indexed.unstack(columns_listlike)
#
# File ~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py:8407, in DataFrame.unstack(self, level, fill_value)
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=8348'>8349</a> """
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=8349'>8350</a> Pivot a level of the (necessarily hierarchical) index labels.
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=8350'>8351</a>
#    (...)
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=8402'>8403</a> dtype: float64
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=8403'>8404</a> """
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=8404'>8405</a> from pandas.core.reshape.reshape import unstack
# -> <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=8406'>8407</a> result = unstack(self, level, fill_value)
#    <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/frame.py?line=8408'>8409</a> return result.__finalize__(self, method="unstack")
#
# File ~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:478, in unstack(obj, level, fill_value)
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=475'>476</a> if isinstance(obj, DataFrame):
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=476'>477</a>     if isinstance(obj.index, MultiIndex):
# --> <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=477'>478</a>         return _unstack_frame(obj, level, fill_value=fill_value)
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=478'>479</a>     else:
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=479'>480</a>         return obj.T.stack(dropna=False)
#
# File ~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:501, in _unstack_frame(obj, level, fill_value)
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=498'>499</a> def _unstack_frame(obj, level, fill_value=None):
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=499'>500</a>     if not obj._can_fast_transpose:
# --> <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=500'>501</a>         unstacker = _Unstacker(obj.index, level=level)
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=501'>502</a>         mgr = obj._mgr.unstack(unstacker, fill_value=fill_value)
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=502'>503</a>         return obj._constructor(mgr)
#
# File ~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:140, in _Unstacker.__init__(self, index, level, constructor)
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=132'>133</a> if num_cells > np.iinfo(np.int32).max:
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=133'>134</a>     warnings.warn(
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=134'>135</a>         f"The following operation may generate {num_cells} cells "
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=135'>136</a>         f"in the resulting pandas object.",
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=136'>137</a>         PerformanceWarning,
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=137'>138</a>     )
# --> <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=139'>140</a> self._make_selectors()
#
# File ~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:192, in _Unstacker._make_selectors(self)
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=188'>189</a> mask.put(selector, True)
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=190'>191</a> if mask.sum() < len(self.index):
# --> <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=191'>192</a>     raise ValueError("Index contains duplicate entries, cannot reshape")
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=193'>194</a> self.group_index = comp_index
#     <a href='file:///~/KCL/5CCS2SEG/sick-legends/venv/lib/python3.9/site-packages/pandas/core/reshape/reshape.py?line=194'>195</a> self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
club_user_age_location_pivot_matrix_df = club_user_age_location_pivot_matrix_df.values
club_user_age_location_pivot_matrix_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/laurenceandrews/KCL/5CCS2SEG/sick-legends/clubs/club-to-user-recommender/club-to-user-recommender.ipynb Cell 21' in <module>
# ----> <a href='vscode-notebook-cell:/Users/laurenceandrews/KCL/5CCS2SEG/sick-legends/clubs/club-to-user-recommender/club-to-user-recommender.ipynb#ch0000018?line=0'>1</a> club_user_age_location_pivot_matrix_df = club_user_age_location_pivot_matrix_df.values
#       <a href='vscode-notebook-cell:/Users/laurenceandrews/KCL/5CCS2SEG/sick-legends/clubs/club-to-user-recommender/club-to-user-recommender.ipynb#ch0000018?line=1'>2</a> club_user_age_location_pivot_matrix_df
#
# NameError: name 'club_user_age_location_pivot_matrix_df' is not defined

# %%
from scipy.sparse.linalg import svds

NUMBER_OF_FACTORS_MF = 15

#Performs matrix factorization of the original user item matrix
U, sigma, Vt = svds(club_user_age_location_pivot_matrix_df, k = NUMBER_OF_FACTORS_MF)

# %%
sigma = np.diag(sigma)
sigma.shape
# Out:
# (15, 15)

# %%
all_clubs_books = np.dot(np.dot(U, sigma), Vt) 
all_user_predicted_books
# Out:
# array([[ 0.00000000e+00,  3.01145261e-34, -1.44341941e-34, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  3.58780903e-38, -3.19805495e-38, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  5.38921851e-35, -1.80280872e-34, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        ...,
#        [ 0.00000000e+00,  1.53681908e-35, -3.57548715e-36, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  3.91903239e-34, -5.66829937e-36, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00, -1.00020459e-35, -1.05741351e-34, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
def top_cosine_similarity(data, club_id, top_n=10):
    index = club_id 
    club_row = data[index, :]
    magnitude = np.sqrt(np.einsum('ij, ij -> i', data, data))
    similarity = np.dot(club_row, data.T) / (magnitude[index] * magnitude)
    sort_indexes = np.argsort(-similarity)
    return sort_indexes[:top_n]

def similar_clubs(club_user_book, club_id, top_indexes):
    print('Recommendations for {0}: \n'.format(
    club_user_book[club_user_book.unique_id_club == club_id]['Book-Title'].values[0]))
    for id in top_indexes + 1:
        print(club_user_book[club_user_book.unique_id_club == id]['Book-Title'].values[0])

# %%
k = 50
movie_id =25954  
top_n = 3
sliced = Vt.T[:, :k] # representative data

similar_clubs(club_user_book, 25954, top_cosine_similarity(sliced, movie_id, top_n))
# Out:
# Recommendations for Pulse Points:
#
# The Witchfinder (Amos Walker Mystery Series)
# Alone in a Crowd (Harper Monogram)
# Jackie Oh
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %% [markdown]
# # Example link:
#
# https://book-recommendation-system-svd.herokuapp.com/
