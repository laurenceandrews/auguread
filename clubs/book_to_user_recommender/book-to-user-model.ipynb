# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_books = pd.read_csv('clubs_book.csv', encoding='latin1')
df_users = pd.read_csv('clubs_user.csv', encoding='latin1')
df_ratings = pd.read_csv('ratings.csv', encoding='latin1', sep=';')

# %% [markdown]
# ### Cleaning all data

# %% [markdown]
# ### df books

# %%
df_books.head(10)
# Out:
#    id        ISBN                                              title  \
# 0   1  0393310779                                      The Greek Way
# 1   2  0399136487                                      Damia (Rowan)
# 2   3  1551051729  Ghost Stories and Mysterious Creatures of Brit...
# 3   4  1402201435                                 The One True Ocean
# 4   5  0060926546             Murder on a Kibbutz : Communal Case, A
# 5   6  0844239062                   Astrology (Teach Yourself Books)
# 6   7  0425068145                                Promise Me the Dawn
# 7   8  0373078188  Wife, Mother ... Lover? (Harlequin Silhouette ...
# 8   9  0446604623             A King's Cutter (Nathaniel Drinkwater)
# 9  10  1585671274  South from the Limpopo: Travels Through South ...
#
#               author               publisher  publication_year
# 0     Edith Hamilton  W. W. Norton & Company              1993
# 1     Anne McCaffrey        Putnam Pub Group              1992
# 2      Barbara Smith    Lone Pine Publishing              1999
# 3  Sarah Beth Martin    Sourcebooks Landmark              2003
# 4          Batya Gur               Perennial              1995
# 5          Jeff Mayo             McGraw-Hill              1992
# 6       Jill Gregory       Berkley Pub Group              1984
# 7  Sally Tyler Hayes              Silhouette              1997
# 8    Richard Woodman       Warner Books (Mm)              1997
# 9      Dervla Murphy          Overlook Press              2001

# %%
# columns to keep
df_books_cleaned = df_books[['ISBN','title', 'author','publication_year','publisher']]

# %%
df_books_cleaned.head()
# Out:
#          ISBN                                              title  \
# 0  0393310779                                      The Greek Way
# 1  0399136487                                      Damia (Rowan)
# 2  1551051729  Ghost Stories and Mysterious Creatures of Brit...
# 3  1402201435                                 The One True Ocean
# 4  0060926546             Murder on a Kibbutz : Communal Case, A
#
#               author  publication_year               publisher
# 0     Edith Hamilton              1993  W. W. Norton & Company
# 1     Anne McCaffrey              1992        Putnam Pub Group
# 2      Barbara Smith              1999    Lone Pine Publishing
# 3  Sarah Beth Martin              2003    Sourcebooks Landmark
# 4          Batya Gur              1995               Perennial

# %%
# clean all rows that contained some nan
df_books_cleaned = df_books_cleaned.dropna(how='any')

# %%
df_books_cleaned.head()
# Out:
#          ISBN                                              title  \
# 0  0393310779                                      The Greek Way
# 1  0399136487                                      Damia (Rowan)
# 2  1551051729  Ghost Stories and Mysterious Creatures of Brit...
# 3  1402201435                                 The One True Ocean
# 4  0060926546             Murder on a Kibbutz : Communal Case, A
#
#               author  publication_year               publisher
# 0     Edith Hamilton              1993  W. W. Norton & Company
# 1     Anne McCaffrey              1992        Putnam Pub Group
# 2      Barbara Smith              1999    Lone Pine Publishing
# 3  Sarah Beth Martin              2003    Sourcebooks Landmark
# 4          Batya Gur              1995               Perennial

# %%
# save books that are published between 1950 to 2016

df_books_cleaned = df_books_cleaned[(df_books_cleaned['publication_year'] > 1950) & (df_books_cleaned['publication_year'] <= 2016)]

# %%
df_books_cleaned[['publication_year']].describe()
# Out:
#        publication_year
# count        491.000000
# mean        1993.250509
# std            7.814976
# min         1963.000000
# 25%         1988.000000
# 50%         1995.000000
# 75%         1999.500000
# max         2004.000000

# %%
# regex-based replacement of certain characters
df_books_cleaned['author'] = df_books_cleaned['author'].str.replace(r'[^\w\s]+', '')
# Out:
# /tmp/ipykernel_45459/1080202894.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_books_cleaned['author'] = df_books_cleaned['author'].str.replace(r'[^\w\s]+', '')

# %% [markdown]
# ### df users

# %%
# cleaned all rows that contained some nan
# df_users_cleaned = df_users.dropna(how='any')

# %%
df_users.head()
# Out:
#       password  last_login  is_superuser  is_staff  is_active date_joined  \
# 0  Password123         NaN             0         0          1  2022-02-18
# 1  Password123         NaN             0         0          1  2022-02-18
# 2  Password123         NaN             0         0          1  2022-02-18
# 3  Password123         NaN             0         0          1  2022-02-18
# 4  Password123         NaN             0         0          1  2022-02-18
#
#                username      id first_name last_name  age  \
# 0   @SylviaMiller109044  109044     Sylvia    Miller   64
# 1    @StaceyBegum185532  185532     Stacey     Begum  147
# 2   @DorothyStone145929  145929    Dorothy     Stone  105
# 3  @EdwardBradley170814  170814     Edward   Bradley   42
# 4     @JanetSmart104159  104159      Janet     Smart   22
#
#                               email         bio                        country
# 0   Sylvia.Miller109044@example.com   Ea optio.   oklahoma city, oklahoma, usa
# 1    Stacey.Begum185532@example.com      Error.  san fracisco, california, usa
# 2   Dorothy.Stone145929@example.com  Inventore.   bad homburg, hessen, germany
# 3  Edward.Bradley170814@example.com    Aliquam.        messina, sicilia, italy
# 4     Janet.Smart104159@example.com   Suscipit.    forest lake, minnesota, usa

# %%
# clean rows with crazy age
df_users_cleaned = df_users[df_users['age']<=100]
df_users_cleaned
# Out:
#         password  last_login  is_superuser  is_staff  is_active date_joined  \
# 0    Password123         NaN             0         0          1  2022-02-18
# 3    Password123         NaN             0         0          1  2022-02-18
# 4    Password123         NaN             0         0          1  2022-02-18
# 7    Password123         NaN             0         0          1  2022-02-18
# 8    Password123         NaN             0         0          1  2022-02-18
# ..           ...         ...           ...       ...        ...         ...
# 493  Password123         NaN             0         0          1  2022-02-18
# 494  Password123         NaN             0         0          1  2022-02-18
# 497  Password123         NaN             0         0          1  2022-02-18
# 498  Password123         NaN             0         0          1  2022-02-18
# 499  Password123         NaN             0         0          1  2022-02-18
#
#                   username      id first_name last_name  age  \
# 0      @SylviaMiller109044  109044     Sylvia    Miller   64
# 3     @EdwardBradley170814  170814     Edward   Bradley   42
# 4        @JanetSmart104159  104159      Janet     Smart   22
# 7           @FionaHill1300    1300      Fiona      Hill   20
# 8    @MitchellMiller217681  217681   Mitchell    Miller   89
# ..                     ...     ...        ...       ...  ...
# 493     @PamelaEdwards6326    6326     Pamela   Edwards   99
# 494      @GeorgeBryan47409   47409     George     Bryan   91
# 497    @DonaldTurner214054  214054     Donald    Turner   94
# 498         @MarcRose61447   61447       Marc      Rose   21
# 499     @LauraGordon142685  142685      Laura    Gordon   69
#
#                                  email        bio  \
# 0      Sylvia.Miller109044@example.com  Ea optio.
# 3     Edward.Bradley170814@example.com   Aliquam.
# 4        Janet.Smart104159@example.com  Suscipit.
# 7           Fiona.Hill1300@example.com       Aut.
# 8    Mitchell.Miller217681@example.com  Repellat.
# ..                                 ...        ...
# 493     Pamela.Edwards6326@example.com     Iusto.
# 494      George.Bryan47409@example.com    Ut aut.
# 497    Donald.Turner214054@example.com       Est.
# 498         Marc.Rose61447@example.com      Nemo.
# 499     Laura.Gordon142685@example.com   Laborum.
#
#                                  country
# 0           oklahoma city, oklahoma, usa
# 3                messina, sicilia, italy
# 4            forest lake, minnesota, usa
# 7              wauwatosa, wisconsin, usa
# 8                oak hill, virginia, usa
# ..                                   ...
# 493               baxter, tennessee, usa
# 494  vancouver, british columbia, canada
# 497              bern, bern, switzerland
# 498         candler, north carolina, usa
# 499             spokane, washington, usa
#
# [334 rows x 14 columns]

# %% [markdown]
# ### df ratings

# %%
# eliminate nans first
df_ratings_cleaned = df_ratings.dropna(how='any')

# %%
# remove zero rating 
df_ratings_cleaned.drop(df_ratings_cleaned[df_ratings_cleaned ['Book-Rating'] == 0].index, inplace = True)

# %%
# ratings distribution 
df_ratings_cleaned.groupby(['Book-Rating']).count() / len(df_ratings_cleaned) * 100
# Out:
#                User-ID       ISBN
# Book-Rating
# 1             0.408144   0.408144
# 2             0.636197   0.636197
# 3             1.382615   1.382615
# 4             2.053169   2.053169
# 5            11.754072  11.754072
# 6             8.514288   8.514288
# 7            17.630185  17.630185
# 8            23.920437  23.920437
# 9            15.574249  15.574249
# 10           18.126644  18.126644

# %%
# ratings by count
df_ratings_cleaned.groupby(['Book-Rating']).count()
# Out:
#              User-ID    ISBN
# Book-Rating
# 1               1770    1770
# 2               2759    2759
# 3               5996    5996
# 4               8904    8904
# 5              50974   50974
# 6              36924   36924
# 7              76457   76457
# 8             103736  103736
# 9              67541   67541
# 10             78610   78610

# %% [markdown]
# ## Model 1
#
# #### top books and authors

# %%
df_books_cleaned
# Out:
#            ISBN                                              title  \
# 0    0393310779                                      The Greek Way
# 1    0399136487                                      Damia (Rowan)
# 2    1551051729  Ghost Stories and Mysterious Creatures of Brit...
# 3    1402201435                                 The One True Ocean
# 4    0060926546             Murder on a Kibbutz : Communal Case, A
# ..          ...                                                ...
# 495  0394586131                              Callanetics Countdown
# 496  0375702008                                      Mal de amores
# 497  0373286856     Stark Lightning (Harlequin Historical, No. 85)
# 498  0802135234  Picasso at the Lapin Agile and Other Plays : P...
# 499  0812556038  The Golden Horn (The Hound and the Falcon Tril...
#
#                 author  publication_year               publisher
# 0       Edith Hamilton              1993  W. W. Norton & Company
# 1       Anne McCaffrey              1992        Putnam Pub Group
# 2        Barbara Smith              1999    Lone Pine Publishing
# 3    Sarah Beth Martin              2003    Sourcebooks Landmark
# 4            Batya Gur              1995               Perennial
# ..                 ...               ...                     ...
# 495    Callan Pinckney              1990            Random House
# 496  Angeles Mastretta              1998       Vintage Books USA
# 497        Elaine Rome              1991               Harlequin
# 498       Steve Martin              1997             Grove Press
# 499        Judith Tarr              1986          Tor Books (Mm)
#
# [491 rows x 5 columns]

# %% [markdown]
# ##### top 20 highest rated books

# %%
# top 20 highest rated books 

top_20_books = df_ratings_cleaned.groupby('ISBN').agg(['mean', 'count'])['Book-Rating'].reset_index()

# generate score based on mean rating and total number of times the book is rated
minVotes = top_20_books['count'].quantile(0.10) # minimum votes required to be listed in the Top 250
top_20_books = top_20_books[top_20_books['count']>minVotes]
print('minimum votes = ', minVotes)
print(top_20_books.shape)
R = top_20_books['mean'] # average for the book (mean) = (Rating)
v = top_20_books['count'] # number of votes for the book = (votes)
C = top_20_books['mean'].mean() # mean vote across all books
top_20_books['weighted rating'] = (v/(v+minVotes))*R + (minVotes/(v+minVotes))*C
top_20_books = top_20_books.sort_values('weighted rating', ascending=False).reset_index(drop=True)

# get title of books
top_20_books = pd.merge(top_20_books, df_books_cleaned, on='ISBN')[['title', 'author', 'mean', 'count', 'weighted rating', 
                              'publication_year']].drop_duplicates('title').iloc[:20]
top_20_books
# Out:
# minimum votes =  1.0
# (56352, 3)
#                                                 title               author  \
# 0                          The Killer Angels: A Novel       Michael Shaara
# 1                        The Bronze Horseman: A Novel      Paullina Simons
# 2           Zen and the Art of Motorcycle Maintenance      Robert M Pirsig
# 3                               A Whisper of Eternity        Amanda Ashley
# 4     The Fortunate Four: Other Journeys of the Heart             Joy Kuby
# 5                             Masks of the Illuminati      ROBERT A WILSON
# 6           Little Women (Illustrated Junior Library)    Louisa May Alcott
# 7                                     The Fairy Rebel     Lynne Reid Banks
# 8       Past Reason Hated: An Inspector Banks Mystery       Peter Robinson
# 9                                   Some of the Parts             T Cooper
# 10            The Story of the House of Wooden Santas          Kevin Major
# 11              The Client (Penguin Readers, Level 4)         John Grisham
# 12  Betty Crocker's New Cookbook: Everything You N...        Betty Crocker
# 13                                            Scandal         Amanda Quick
# 14                                             Elixir          Gary Braver
# 15                                         Gatekeeper         Archer Mayor
# 16            Much Ado About Nothing (Bantam Classic)  William Shakespeare
# 17                                          Awakening          Kate Chopin
# 18  Crime and Punishment: A Novel in Six Parts Wit...   Fyodor Dostoyevsky
# 19                   El Cuento de La Isla Desconocida        Jose Saramago
#
#          mean  count  weighted rating  publication_year
# 0   10.000000      3         9.391798              1993
# 1   10.000000      3         9.391798              2001
# 2    9.750000      4         9.313438              1981
# 3   10.000000      2         9.189063              2004
# 4   10.000000      2         9.189063              2003
# 5   10.000000      2         9.189063              1990
# 6    9.000000     10         8.869745              1983
# 7    9.500000      2         8.855730              1989
# 8    9.000000      3         8.641798              2000
# 9    9.000000      2         8.522397              2002
# 10   9.000000      2         8.522397              1998
# 11   9.000000      2         8.522397              2000
# 12   8.666667      6         8.509599              1996
# 13   8.500000     10         8.415199              1991
# 14   8.666667      3         8.391798              2000
# 15   8.666667      3         8.391798              2003
# 16   8.500000      2         8.189063              1988
# 17   8.500000      2         8.189063              1985
# 18   8.500000      2         8.189063              1993
# 19   8.500000      2         8.189063              1999

# %%
# top 20 highest rated authors

# drop any duplicates
df_books_cleaned = df_books_cleaned.drop_duplicates(['author', 'title'])

# get book-author and title
highest_rated_author = pd.merge(df_books_cleaned, df_ratings_cleaned, on='ISBN')[['author', 'Book-Rating', 'title', 'ISBN']]

highest_rated_author = highest_rated_author.groupby('author').agg(['mean', 'count'])['Book-Rating'].reset_index()

# generate score based on mean rating and total number of times the author is rated
m = highest_rated_author['count'].quantile(0.6) # minimum votes required to be listed in the Top 250
highest_rated_author = highest_rated_author[highest_rated_author['count']>m]
print('minimum votes =', m)
print(highest_rated_author.shape)
R = highest_rated_author['mean'] # average for the author (mean) = (Rating)
v = highest_rated_author['count'] # number of votes for the author = (votes)
C = highest_rated_author['mean'].mean() # mean vote across all authors
highest_rated_author['weighted rating'] = (v/(v+m))*R + (m/(v+m))*C
highest_rated_author = highest_rated_author.sort_values('weighted rating', ascending=False).reset_index(drop=True)

highest_rated_author.iloc[:20]
# Out:
# minimum votes = 1.0
# (91, 3)
# /tmp/ipykernel_45459/53270508.py:9: FutureWarning: ['title', 'ISBN'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   highest_rated_author = highest_rated_author.groupby('author').agg(['mean', 'count'])['Book-Rating'].reset_index()
#                  author       mean  count  weighted rating
# 0        Michael Shaara  10.000000      3         9.365923
# 1       Paullina Simons  10.000000      3         9.365923
# 2       Robert M Pirsig   9.750000      4         9.292738
# 3         Amanda Ashley  10.000000      2         9.154564
# 4              Joy Kuby  10.000000      2         9.154564
# 5       ROBERT A WILSON  10.000000      2         9.154564
# 6     Louisa May Alcott   9.000000     10         8.860336
# 7      Lynne Reid Banks   9.500000      2         8.821230
# 8        Peter Robinson   9.000000      3         8.615923
# 9         Betty Crocker   8.666667      6         8.494813
# 10         John Grisham   9.000000      2         8.487897
# 11          Kevin Major   9.000000      2         8.487897
# 12             T Cooper   9.000000      2         8.487897
# 13         Amanda Quick   8.500000     10         8.405790
# 14          Gary Braver   8.666667      3         8.365923
# 15         Archer Mayor   8.666667      3         8.365923
# 16          Kate Chopin   8.500000      2         8.154564
# 17        Jose Saramago   8.500000      2         8.154564
# 18   Fyodor Dostoyevsky   8.500000      2         8.154564
# 19  William Shakespeare   8.500000      2         8.154564

# %%
# top 20 as list 

# highest_rated_author.values.tolist()

# %% [markdown]
# ## Model 2 - collaborative filtering
#
# #### Based on records from various users provide recommendations based on user similarities

# %%
# merge ratings and books to get book titles and drop rows for which title is not available
df_books_ratings = pd.merge(df_ratings_cleaned, df_books_cleaned, on='ISBN')

# get total counts of no. of occurrence of book
df_books_ratings['count'] = df_books_ratings.groupby('ISBN').transform('count')['User-ID']

# fetch top 100 books based on count
isbn = df_books_ratings.drop_duplicates('ISBN').sort_values(
    'count', ascending=False).iloc[:100]['ISBN']

# filter out data as per the ISBN
df_books_ratings = df_books_ratings[df_books_ratings['ISBN'].isin(isbn)].reset_index(drop=True)

# %%
# create a user-book rating matrix
matrix = df_books_ratings.pivot(index='User-ID', columns='ISBN', values='Book-Rating')
matrix.head()
# Out:
# ISBN     0028603958  0060199261  0060199865  006105206X  0061083089  \
# User-ID
# 3167            NaN         NaN         NaN         NaN         NaN
# 4197            NaN         NaN         NaN         NaN         NaN
# 5499            NaN         NaN         NaN         NaN         NaN
# 7418            NaN         NaN         NaN         NaN         NaN
# 8936            NaN         NaN         NaN         NaN         NaN
#
# ISBN     0099282194  0140285563  0195108973  0198319746  0310235138  ...  \
# User-ID                                                              ...
# 3167            NaN         NaN         NaN         NaN         NaN  ...
# 4197            NaN         NaN         NaN         NaN         NaN  ...
# 5499            NaN         NaN         NaN         NaN         NaN  ...
# 7418            NaN         NaN         NaN         NaN         NaN  ...
# 8936            NaN         NaN         NaN         NaN         NaN  ...
#
# ISBN     1586212044  1592864996  1592980074  1853260126  185326217X  \
# User-ID
# 3167            NaN         NaN         NaN         NaN         NaN
# 4197            NaN         NaN         NaN         NaN         NaN
# 5499            NaN         NaN         NaN         NaN         NaN
# 7418            NaN         NaN         NaN         NaN         NaN
# 8936            NaN         NaN         NaN         NaN         NaN
#
# ISBN     188845136X  3442421705  8408022466  8420429902  950511446X
# User-ID
# 3167            NaN         NaN         NaN         NaN         NaN
# 4197            NaN         NaN         NaN         NaN         NaN
# 5499            NaN         NaN         NaN         NaN         NaN
# 7418            NaN         NaN         NaN         NaN         NaN
# 8936            NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 100 columns]

# %%
from surprise import Reader, Dataset, SVD
from surprise.model_selection import train_test_split, cross_validate

# %%
reader = Reader(rating_scale=(0, 10))
surprise_data = Dataset.load_from_df(df_books_ratings[['User-ID', 'ISBN', 'Book-Rating']], reader)
trainset, testset = train_test_split(surprise_data, test_size=0.25)

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD()]:
    # Perform cross validation
    results = cross_validate(algorithm, surprise_data, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# /tmp/ipykernel_45459/1167096262.py:9: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
#            test_rmse  fit_time  test_time
# Algorithm
# SVD         1.864433  0.027152   0.001106

# %%
svd = SVD() 
svd.fit(trainset)

# %% [markdown]
# ## create predictions

# %%
index_val = 111
# get user id
userId = matrix.index[index_val]
books = []
ratings = [] 
titles = []

for isbn in matrix.iloc[index_val][matrix.iloc[index_val].isna()].index:
    books.append(isbn)
    title = df_books_ratings[df_books_ratings['ISBN']==isbn]['title'].values[0]
    titles.append(title)
    ratings.append(svd.predict(userId, isbn).est)

prediction = pd.DataFrame({'ISBN':books, 'title':titles, 'rating':ratings, 'userId':userId})  
prediction = prediction.sort_values('rating', ascending=False).iloc[:10].reset_index(drop=True)

# get other highly rated books by user
temp = df_books_ratings[df_books_ratings['User-ID']==matrix.index[index_val]].sort_values(
    'Book-Rating', ascending=False)[['Book-Rating', 'title', 'User-ID']].iloc[:10].reset_index(drop=True)
prediction['Book Read'] = temp['title']
prediction['Rated']= temp['Book-Rating']
prediction
# Out:
#          ISBN                                              title    rating  \
# 0  0679425411                         The Killer Angels: A Novel  8.150466
# 1  1551669153    Split Second (Maggie O'Dell Novels (Paperback))  8.107344
# 2  0553244582          Zen and the Art of Motorcycle Maintenance  8.015314
# 3  0448060191          Little Women (Illustrated Junior Library)  8.012882
# 4  0380733285      Past Reason Hated: An Inspector Banks Mystery  8.011172
# 5  0028603958  Betty Crocker's New Cookbook: Everything You N...  8.008050
# 6  0517542099               The Hitchhiker's Guide to the Galaxy  8.000900
# 7  0553289322                                            Scandal  7.948336
# 8  0399136487                                      Damia (Rowan)  7.928162
# 9  055357003X    The Fowlers of Sweet Valley (Sweet Valley Saga)  7.911012
#
#    userId                                Book Read  Rated
# 0   93047  The Story of the House of Wooden Santas    8.0
# 1   93047                                      NaN    NaN
# 2   93047                                      NaN    NaN
# 3   93047                                      NaN    NaN
# 4   93047                                      NaN    NaN
# 5   93047                                      NaN    NaN
# 6   93047                                      NaN    NaN
# 7   93047                                      NaN    NaN
# 8   93047                                      NaN    NaN
# 9   93047                                      NaN    NaN

# %% [markdown]
# ## Model 3
#
# ### Using mean of other user's weighted ratings based on similarity matrix

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# replace NaN with user based average rating in pivot (matrix) dataframe
matrix_imputed = matrix.fillna(matrix.mean(axis=0))

# get similarity between all users
similarity_matrix = cosine_similarity(matrix_imputed.values)

# %%
def get_recommendation(user_index):
    idx = user_index
    sim_scores = list(enumerate(similarity_matrix[idx]))

    # get books that are unrated by the given user
    unrated_books = matrix.iloc[idx][matrix.iloc[idx].isna()].index

    # get weighted ratings of unrated books by all other users
    book_ratings = (matrix[unrated_books].T * similarity_matrix[idx]).T

    # get top 100 similar users by skipping the current user
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:101]

    # get mean of book ratings by top 100 most similar users for the unrated books
    book_ratings = book_ratings.iloc[[x[0] for x in sim_scores]].mean()
    
    # get rid of null values and sort it based on ratings
    book_ratings = book_ratings.reset_index().dropna().sort_values(0, ascending=False).iloc[:10]
    
    # get recommended book titles in sorted order
    recommended_books = df_books_ratings[df_books_ratings['ISBN'].isin(book_ratings['ISBN'])][['ISBN', 'title']]
    recommended_books = recommended_books.drop_duplicates('ISBN').reset_index(drop=True)
    assumed_ratings = book_ratings[0].reset_index(drop=True)


    return pd.DataFrame({'ISBN':recommended_books['ISBN'], 
                         'Recommended Book':recommended_books['title'], 
                         'Assumed Rating':assumed_ratings})

# %%
user_index = 211

recommended_books = get_recommendation(user_index)

# get other highly rated books by user
temp = df_books_ratings[df_books_ratings['User-ID']==matrix.index[user_index]].sort_values(
    'Book-Rating', ascending=False)[['Book-Rating', 'title', 'User-ID']].iloc[:10].reset_index(drop=True)
recommended_books['userId'] = temp['User-ID']
recommended_books['Book Read'] = temp['title']
recommended_books['Rated']= temp['Book-Rating']
recommended_books
# Out:
#          ISBN                                   Recommended Book  \
# 0  0380733285      Past Reason Hated: An Inspector Banks Mystery
# 1  0679425411                         The Killer Angels: A Novel
# 2  044050306X                            Masks of the Illuminati
# 3  0553244582          Zen and the Art of Motorcycle Maintenance
# 4  0060199261                       The Bronze Horseman: A Novel
# 5  0821773801                                       Midnight Sun
# 6  0821775294                              A Whisper of Eternity
# 7  0380706504                                    The Fairy Rebel
# 8  0809448777  Wild Animals (A Child's First Library of Learn...
# 9  1592980074    The Fortunate Four: Other Journeys of the Heart
#
#    Assumed Rating    userId                            Book Read  Rated
# 0        9.999782  174642.0  Time Out for Mom . . . Ahhh Moments    7.0
# 1        9.999782       NaN                                  NaN    NaN
# 2        9.999782       NaN                                  NaN    NaN
# 3        9.999782       NaN                                  NaN    NaN
# 4        9.999782       NaN                                  NaN    NaN
# 5        9.999782       NaN                                  NaN    NaN
# 6        9.999731       NaN                                  NaN    NaN
# 7        9.999572       NaN                                  NaN    NaN
# 8        8.999804       NaN                                  NaN    NaN
# 9        8.999464       NaN                                  NaN    NaN
